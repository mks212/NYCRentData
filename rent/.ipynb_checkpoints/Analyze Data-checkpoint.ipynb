# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
df = pd.read_csv('rent_info_cleaned.csv')

df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#                   address  rent beds  baths    borough            hood  \
# 0        201 East 12th St  4195    1      1  Manhattan    East Village
# 1              East 17 st  4200    3      1  Manhattan   Gramercy Park
# 2   507 W 134th St Apt 54  2450    2      2  Manhattan  Manhattanville
# 3               Blue Slip  3035    1      1   Brooklyn      Greenpoint
# 4  97 Second Avenue Apt 9  5000    3      1  Manhattan    East Village
#
#    elevator  doorman  laundry  furnished  sqft  page
# 0      True    False    False      False   NaN     1
# 1      True    False    False      False   NaN     1
# 2     False    False     True      False   NaN     1
# 3      True     True     True      False   NaN     1
# 4     False    False    False      False   NaN     1

# %%
df['borough'].value_counts()
# Out:
# Manhattan        28855
# Brooklyn          5032
# Queens            2761
# Bronx              119
# Staten Island       11
# Name: borough, dtype: int64

# %%
df['hood'].value_counts()
# Out:
# Financial District              3557
# Hell's Kitchen                  2945
# Upper East Side                 2035
# Yorkville                       1797
# Murray Hill                     1454
# Upper West Side                 1373
# Chelsea                         1135
# Rose Hill                        927
# Turtle Bay                       919
# West Village                     911
# Lincoln Square                   887
# East Village                     850
# Long Island City                 829
# Lower East Side                  790
# Theater District                 766
# Williamsburg                     703
# Alphabet City                    664
# Tribeca                          614
# East Harlem                      551
# Hunters Point                    547
# Bushwick                         529
# Gramercy Park                    519
# Astoria                          502
# Downtown Brooklyn                491
# Kips Bay                         475
# Manhattan Valley                 435
# Battery Park City                432
# Bedford-Stuyvesant               431
# Greenwich Village                378
# East Williamsburg                369
#                                 ...
# South Ozone Park                   1
# Blissville                         1
# Stratton Park                      1
# Beechhurst                         1
# University Heights                 1
# Port Morris                        1
# New Brighton                       1
# Prospect Park                      1
# Crotona Park East                  1
# Hollis                             1
# Cypress Hills                      1
# Brookville                         1
# Downtown Flushing                  1
# Pelham                             1
# City Line                          1
# Bergen Beach                       1
# Woodlawn Heights                   1
# Flushing Meadows-Corona Park       1
# St. George                         1
# Bayside                            1
# Downtown Manhattan                 1
# Manhattan Beach                    1
# East Midwood                       1
# Longwood                           1
# Bronxwood                          1
# Ozone Park                         1
# Rockaway Beach                     1
# Midtown Manhattan                  1
# Melrose                            1
# West Farms                         1
# Name: hood, Length: 204, dtype: int64

# %%
df.sort_values(by=['rent'], ascending=False).head(20)
# Out:
#                       address   rent beds  baths    borough  \
# 31699            West 57th St  50000    1      1  Manhattan
# 24610        157 West 57th St  49000    4      4  Manhattan
# 24638            Mulberry St.  47307    3      1  Manhattan
# 10376                Broadway  45500    4      5  Manhattan
# 8463             West 80th St  45000    6      7  Manhattan
# 13987           Meeker Avenue  43750    1      1   Brooklyn
# 32861        443 Greenwich St  42500    4      4  Manhattan
# 29845                Broadway  42000    4      5  Manhattan
# 21681       Washington Street  40000    5      4  Manhattan
# 27054        West 31st Street  39675    1      1  Manhattan
# 23877       Washington Street  39500    5      4  Manhattan
# 27723        370 West 11th St  39000    5      4  Manhattan
# 16705          Washington St.  38995    5      4  Manhattan
# 30551          1 Fifth Avenue  37500    2      2  Manhattan
# 17178        111 East 56th St  35000    3      3  Manhattan
# 35481               West 85th  35000    5      6  Manhattan
# 12265  110 Central Park South  35000    4      5  Manhattan
# 7673           Liberty Street  35000    5      4  Manhattan
# 31304              30 Park Pl  35000    3      3  Manhattan
# 34506            West 57th St  34500    1      1  Manhattan
#
#                      hood  elevator  doorman  laundry  furnished    sqft  page
# 31699    Theater District      True     True    False       True     NaN   492
# 24610    Theater District      True     True     True      False  3466.0  1025
# 24638        Little Italy     False    False     True      False     NaN  1023
# 10376      Lincoln Square     False     True    False      False     NaN  2072
# 8463      Upper West Side      True    False    False      False  8040.0  2205
# 13987        Williamsburg     False    False    False      False     NaN  1822
# 32861             Tribeca      True     True     True      False  4526.0   401
# 29845      Lincoln Square      True     True    False      False     NaN   640
# 21681             Tribeca      True     True     True      False     NaN  1238
# 27054             Chelsea      True     True    False      False     NaN   845
# 23877             Tribeca      True     True     True      False     NaN  1080
# 27723        West Village      True    False    False      False  4334.0   796
# 16705             Tribeca      True     True     True      False     NaN  1620
# 30551   Greenwich Village      True     True     True      False     NaN   587
# 17178        Midtown East      True     True    False      False     NaN  1584
# 35481     Upper West Side      True     True     True      False  5000.0   182
# 12265    Theater District      True     True    False      False  5000.0  1940
# 7673   Financial District      True     True     True      False     NaN  2259
# 31304             Tribeca      True     True    False      False  2631.0   529
# 34506    Theater District      True     True    False       True     NaN   272

# %%
rent_no_outlier = df[df['rent'] <=10000]
sns.distplot(rent_no_outlier['rent'], kde=False)
plt.xlabel('Monthly Rent')
plt.ylabel('Count')
plt.title("Monthly Rent For All Apartments Under $10,000 Through All Boroughs")
plt.gcf().set_size_inches(16, 9)
# Out:
# /Users/michaelsankari/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.boxplot(x='borough', y='rent', data=rent_no_outlier)
plt.xlabel('Borough')
plt.ylabel('Monthly Rent')
plt.title("Rent By Borough For All Apartments Under $10,000")
plt.gcf().set_size_inches(16, 9)

# %%
group = df.groupby(['borough'])
group.agg(['count', 'min', 'max', 'mean', 'median'])['rent']
# Out:
#                count   min    max         mean  median
# borough
# Bronx            119  1325   5100  2155.630252    2000
# Brooklyn        5032   675  43750  3117.754173    2800
# Manhattan      28855   825  50000  4245.421591    3650
# Queens          2761   875  10500  2779.093444    2631
# Staten Island     11  1609   3025  2134.727273    1876

# %%
group = group.agg(['count', 'min', 'max', 'mean', 'median'])['rent']
group.loc[group.index == 'Queens', 'median']
# Out:
# borough
# Queens    2631
# Name: median, dtype: int64

# %% [markdown]
# ## Which neighborhoods in manhattan have cheaper rent than queens

# %%
queens_med = df['rent'][df['borough'] == 'Queens'].median()
manhattan_group = df.loc[df['borough'] == 'Manhattan']
manhattan_group = manhattan_group.groupby('hood')
manhattan_group = manhattan_group.agg(['median'])['rent']
manhattan_group.loc[manhattan_group['median'] < queens_med]
# Out:
#                     median
# hood
# Central Harlem      2395.0
# Fort George         1800.0
# Hamilton Heights    2600.0
# Hudson Heights      2296.0
# Inwood              1897.5
# Manhattanville      2400.0
# Washington Heights  2193.0

# %% [markdown]
# ## Case Study 1: UWS Studio Rental

# %%
uws = df.loc[(df['borough'] == 'Manhattan') & (df['hood'] == 'Upper West Side')]
uws
# Out:
#                                  address   rent    beds  baths    borough  \
# 7             128 West 74th Street Apt B   4400       2      2  Manhattan
# 97                      West 96th Street   3425       2      1  Manhattan
# 104                     West 87th Street   2700       1      1  Manhattan
# 109                        W 93th street  13000       4      4  Manhattan
# 156                        W 88th Street   4125       2      1  Manhattan
# 158                      West End Avenue  14750       4      3  Manhattan
# 169                     West 90th Street   4572       3      1  Manhattan
# 175                               W 93rd   3995       1      1  Manhattan
# 310                     West 77th Street   4045       1      1  Manhattan
# 553                135 Central Park West  12500       2      2  Manhattan
# 572                      Columbus Avenue   4000       1      1  Manhattan
# 579                     West 94th Street   4080       1      1  Manhattan
# 585                     West 94th Street   3510  Studio      1  Manhattan
# 662                     West 94th Street   7960       2      2  Manhattan
# 726                         West 73rd St   2700  Studio      1  Manhattan
# 760                         West 72nd St   1800  Studio      1  Manhattan
# 792                    250 West 100th St   2750       1      1  Manhattan
# 893                         W 107 Street   3300       1      1  Manhattan
# 895                      UPPER WEST SIDE   5900       2      2  Manhattan
# 929                     West 79th Street   5700       2      1  Manhattan
# 984                        W 89th Street   3295       1      1  Manhattan
# 1033   West 83rd St and Riverside Dri...   2050  Studio      1  Manhattan
# 1035                      West 72 Street   2750       1      1  Manhattan
# 1037                    West 77th Street   3600       1      1  Manhattan
# 1060                    Amsterdam Avenue   4685       1      1  Manhattan
# 1100                   CENTRAL PARK WEST   8600       3      3  Manhattan
# 1147                     UPPER WEST SIDE   8300       4      3  Manhattan
# 1155                    West 78th Street   3995       1      1  Manhattan
# 1191                2532 Broadway Apt 21   2200       1      1  Manhattan
# 1194                           West 83rd   2195       1      1  Manhattan
# ...                                  ...    ...     ...    ...        ...
# 35823                          West 70's   5600       2      2  Manhattan
# 35834                         W 79th St.   8000       2      2  Manhattan
# 35935                   West 93rd Street   3688       2      1  Manhattan
# 35940                          West 90's   3300       1      1  Manhattan
# 35941                    West End Avenue  11995       3      3  Manhattan
# 36003                    Upper West Side   5480       2      2  Manhattan
# 36036                         W 72nd St.   3295       1      1  Manhattan
# 36073                   West 93rd Street   3306       2      1  Manhattan
# 36187                   37 W 89th Apt 3A   5000       3      2  Manhattan
# 36191                        250 West 78   2050       1      1  Manhattan
# 36194                   West 74th Street  10000       3      3  Manhattan
# 36233                      W 96th Street   4949       3      2  Manhattan
# 36234                           W 87 St.   6000       3      1  Manhattan
# 36239                         W 91st St.   3796       1      1  Manhattan
# 36256                   West 80th Street   2610       1      1  Manhattan
# 36258                         W 73rd St.   3275       1      1  Manhattan
# 36298            736 Tenth Avenue Apt 2R   3500       1      1  Manhattan
# 36316                           W 90 St.   5000       2      2  Manhattan
# 36318        253 West 91st Street Apt 2C   2000       1      1  Manhattan
# 36323        325 West 87th Street Apt 2A   2300       1      1  Manhattan
# 36327         175 West 90 Street Apt 11A   3350       1      1  Manhattan
# 36340                    West End Avenue  14000       4      3  Manhattan
# 36353         14 West 90th Street Apt 1B   3850       1      2  Manhattan
# 36377        306 West 76th Street Apt 3C   4250       2      2  Manhattan
# 36492                   334 West 87th St   3850       1      1  Manhattan
# 36604                         W 87th St.  10355       4      2  Manhattan
# 36618                          W 91st St   3346       1      1  Manhattan
# 36676                   160 West 73rd St   2700  Studio      1  Manhattan
# 36690                             W 73rd   3275       1      1  Manhattan
# 36704                        W 73 Street   3275       1      1  Manhattan
#
#                   hood  elevator  doorman  laundry  furnished    sqft  page
# 7      Upper West Side     False    False    False      False  1100.0     1
# 97     Upper West Side      True     True    False      False     NaN    38
# 104    Upper West Side     False    False    False      False     NaN    37
# 109    Upper West Side      True     True     True      False     NaN    37
# 156    Upper West Side     False    False    False      False     NaN    33
# 158    Upper West Side      True     True     True      False     NaN    32
# 169    Upper West Side      True     True    False      False     NaN    31
# 175    Upper West Side      True     True    False      False     NaN    30
# 310    Upper West Side      True     True    False      False   627.0  2809
# 553    Upper West Side      True     True    False      False     NaN  2783
# 572    Upper West Side      True     True     True      False   643.0  2781
# 579    Upper West Side      True     True    False      False     NaN  2778
# 585    Upper West Side      True     True    False      False     NaN  2778
# 662    Upper West Side      True     True    False      False     NaN  2774
# 726    Upper West Side      True     True    False      False     NaN  2765
# 760    Upper West Side      True    False    False      False   142.0  2761
# 792    Upper West Side      True     True    False      False     NaN  2755
# 893    Upper West Side     False    False    False      False     NaN  2739
# 895    Upper West Side      True     True    False      False  1300.0  2739
# 929    Upper West Side      True     True    False      False  1050.0  2735
# 984    Upper West Side      True     True    False      False   695.0  2728
# 1033   Upper West Side      True    False    False      False     NaN  2726
# 1035   Upper West Side     False    False    False      False     NaN  2725
# 1037   Upper West Side     False    False    False      False     NaN  2725
# 1060   Upper West Side      True     True     True      False   655.0  2724
# 1100   Upper West Side      True     True     True      False  1800.0  2721
# 1147   Upper West Side      True     True     True      False     NaN  2718
# 1155   Upper West Side     False    False     True      False     NaN  2718
# 1191   Upper West Side     False    False    False      False   450.0  2716
# 1194   Upper West Side     False    False    False      False     NaN  2715
# ...                ...       ...      ...      ...        ...     ...   ...
# 35823  Upper West Side      True     True     True      False     NaN   145
# 35834  Upper West Side      True     True     True      False  1700.0   144
# 35935  Upper West Side      True     True    False      False     NaN   134
# 35940  Upper West Side      True     True    False      False     NaN   133
# 35941  Upper West Side      True     True     True      False  2086.0   133
# 36003  Upper West Side      True     True     True      False     NaN   126
# 36036  Upper West Side      True     True    False      False     NaN   123
# 36073  Upper West Side      True     True     True      False     NaN   117
# 36187  Upper West Side     False    False     True      False  1300.0   103
# 36191  Upper West Side     False    False    False      False     NaN   103
# 36194  Upper West Side      True     True     True      False     NaN   103
# 36233  Upper West Side      True     True    False      False     NaN    98
# 36234  Upper West Side      True     True    False      False     NaN    98
# 36239  Upper West Side      True     True    False      False     NaN    97
# 36256  Upper West Side     False    False    False      False     NaN    95
# 36258  Upper West Side      True    False    False      False     NaN    95
# 36298  Upper West Side     False    False     True      False     NaN    91
# 36316  Upper West Side      True     True     True      False     NaN    88
# 36318  Upper West Side     False    False    False      False     NaN    88
# 36323  Upper West Side     False    False    False      False     NaN    87
# 36327  Upper West Side      True     True    False      False     NaN    87
# 36340  Upper West Side      True     True     True      False  3000.0    85
# 36353  Upper West Side     False    False    False      False     NaN    84
# 36377  Upper West Side      True    False    False      False     NaN    80
# 36492  Upper West Side      True    False    False      False   750.0    61
# 36604  Upper West Side      True     True     True      False     NaN    28
# 36618  Upper West Side     False    False    False      False     NaN    26
# 36676  Upper West Side      True     True    False      False     NaN    16
# 36690  Upper West Side      True    False    False      False   700.0    13
# 36704  Upper West Side      True    False    False      False     NaN    11
#
# [1373 rows x 12 columns]

# %%
uws_group = uws.groupby('beds')
uws_group.agg(['count', 'min', 'max', 'mean', 'median'])['rent']
# Out:
#         count    min    max          mean   median
# beds
# 1         484   1506   6785   3160.057851   3000.0
# 2         347   2420  12500   4628.740634   4268.0
# 3         224   3800  23925   7899.772321   7172.5
# 4         101   4500  22000  10229.168317   9378.0
# 5           7   5475  35000  16735.714286  15000.0
# 6           1  45000  45000  45000.000000  45000.0
# Loft        2   2350   2690   2520.000000   2520.0
# Studio    207   1600   7750   2469.415459   2350.0

# %%
uws_studios = uws.loc[(uws['beds'] == 'Studio') & (uws['rent'] <5000)] #remove outlier at $7,750
uws_studios.sample(10)
# Out:
#                                address  rent    beds  baths    borough  \
# 9319                  West 96th Street  2390  Studio      1  Manhattan
# 34284              34 West 86th street  1895  Studio      1  Manhattan
# 31639                 West 77th Street  2470  Studio      1  Manhattan
# 24486                 West 93rd Street  3350  Studio      1  Manhattan
# 33739       34 West 86th Street Apt 5C  1895  Studio      1  Manhattan
# 22742                        W 91st St  2280  Studio      1  Manhattan
# 28844  210 West 89th Apt. 8b Apt 8B...  3112  Studio      1  Manhattan
# 22336                       W 72nd St.  2025  Studio      1  Manhattan
# 19009                 West 73rd Street  2650  Studio      1  Manhattan
# 28698         250 West 93rd St Apt 14D  3350  Studio      1  Manhattan
#
#                   hood  elevator  doorman  laundry  furnished   sqft  page
# 9319   Upper West Side      True     True    False      False  450.0  2147
# 34284  Upper West Side      True    False    False      False    NaN   289
# 31639  Upper West Side      True     True    False      False    NaN   498
# 24486  Upper West Side      True     True     True      False    NaN  1035
# 33739  Upper West Side      True    False    False      False    NaN   331
# 22742  Upper West Side      True     True    False      False    NaN  1164
# 28844  Upper West Side      True     True    False      False  600.0   715
# 22336  Upper West Side      True    False    False      False    NaN  1192
# 19009  Upper West Side     False    False    False      False    NaN  1449
# 28698  Upper West Side      True     True    False      False    NaN   725

# %%
pd.set_option('display.max_columns', 50)
uws_studios['el_no_doorman'] =  (uws_studios['elevator']) & (~uws_studios['doorman'])
# Out:
# /Users/michaelsankari/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
uws_studios.sample(20)
# Out:
#                                  address  rent    beds  baths    borough  \
# 34171               335 West 76th street  2575  Studio      1  Manhattan
# 36676                   160 West 73rd St  2700  Studio      1  Manhattan
# 32689        311 West 95th Street Apt 7C  1600  Studio      1  Manhattan
# 4553                    West 74th Street  2100  Studio      1  Manhattan
# 14593                   West 87th Street  2125  Studio      1  Manhattan
# 13133                   West 84th Street  3662  Studio      1  Manhattan
# 22742                          W 91st St  2280  Studio      1  Manhattan
# 13873                  West 100th Street  2425  Studio      1  Manhattan
# 1599                           West 92nd  2450  Studio      1  Manhattan
# 8702                          W 79th St.  2350  Studio      1  Manhattan
# 31773                   West 96th Street  2520  Studio      1  Manhattan
# 1383                    West 91st Street  2195  Studio      1  Manhattan
# 35585                         W 72nd St.  2075  Studio      1  Manhattan
# 24916                   West 86th Street  2455  Studio      1  Manhattan
# 35195               78 W 85th St. Apt 4C  2500  Studio      1  Manhattan
# 30519                             W 87th  3400  Studio      1  Manhattan
# 3262                            Broadway  1850  Studio      1  Manhattan
# 1033   West 83rd St and Riverside Dri...  2050  Studio      1  Manhattan
# 5217                    West 72nd Street  2100  Studio      1  Manhattan
# 30944                   West 83rd Street  2995  Studio      1  Manhattan
#
#                   hood  elevator  doorman  laundry  furnished   sqft  page  \
# 34171  Upper West Side     False    False    False      False    NaN   298
# 36676  Upper West Side      True     True    False      False    NaN    16
# 32689  Upper West Side     False    False    False      False    NaN   415
# 4553   Upper West Side     False    False    False      False    NaN  2490
# 14593  Upper West Side     False    False    False      False    NaN  1777
# 13133  Upper West Side     False    False     True      False    NaN  1880
# 22742  Upper West Side      True     True    False      False    NaN  1164
# 13873  Upper West Side      True     True    False      False    NaN  1830
# 1599   Upper West Side     False    False    False      False    NaN  2687
# 8702   Upper West Side     False    False    False      False    NaN  2189
# 31773  Upper West Side      True     True    False      False    NaN   486
# 1383   Upper West Side      True     True    False      False    NaN  2701
# 35585  Upper West Side      True    False    False      False    NaN   173
# 24916  Upper West Side      True     True    False      False    NaN  1003
# 35195  Upper West Side      True    False    False       True    NaN   209
# 30519  Upper West Side      True     True    False      False  700.0   589
# 3262   Upper West Side      True     True    False      False    NaN  2578
# 1033   Upper West Side      True    False    False      False    NaN  2726
# 5217   Upper West Side      True    False    False      False    NaN  2445
# 30944  Upper West Side     False    False    False       True    NaN   556
#
#        el_no_doorman
# 34171          False
# 36676          False
# 32689          False
# 4553           False
# 14593          False
# 13133          False
# 22742          False
# 13873          False
# 1599           False
# 8702           False
# 31773          False
# 1383           False
# 35585           True
# 24916          False
# 35195           True
# 30519          False
# 3262           False
# 1033            True
# 5217            True
# 30944          False

# %%
sns.boxplot(x='doorman', y='rent', data=uws_studios)
plt.gcf().set_size_inches(11.7, 8.27)

# %%
sns.boxplot(x='el_no_doorman', y='rent', data=uws_studios)
plt.xlabel('Elevator, No Doorman')
plt.title("Suprisingly, No Appreciation For Elevator Without Doorman")
plt.gcf().set_size_inches(11.7, 8.27)

# %%
#elevator equal to false and doorman = to true isn't worth exploring
#uwsGrid = sns.FacetGrid(uws_studios, row='elevator', col='doorman', palette="Set2")
#uwsGrid.map(sns.boxplot,'rent')
#uwsGrid.add_legend()
#plt.gcf().set_size_inches(11.7, 8.27)

# %% [markdown]
# ### Case Study 1 Recommendation: Start Price at \$2,400 & lower by \$50 each week it's not rented until reaching \$2,100.

# %%
sum((~uws_studios['elevator']) & (uws_studios['doorman']))
# Out:
# 1

# %% [markdown]
# ## Case Study 2: 3 Roommates Search For A Brooklyn Apartment

# %%
brook = df.loc[(df['borough'] == 'Brooklyn') & (df['beds'] == '3')]
brook
# Out:
#                                  address  rent beds  baths   borough  \
# 29           265 South 2nd Street Apt 17  3600    3      1  Brooklyn
# 49                   369 South 4th Apt 1  3547    3      1  Brooklyn
# 59                     1038 Greene Apt 2  2992    3      1  Brooklyn
# 101                     307 Grand Apt 3A  4500    3      2  Brooklyn
# 131                          Gold Street  6055    3      3  Brooklyn
# 274                              3RD AVE  2000    3      1  Brooklyn
# 354                       Waverly Avenue  3378    3      1  Brooklyn
# 564                        Clifton Place  4395    3      2  Brooklyn
# 752                        Greene Avenue  2700    3      1  Brooklyn
# 753                       Willoughby Ave  3200    3      1  Brooklyn
# 821             796 East 37 Street Apt 3  2300    3      1  Brooklyn
# 823           2417 Albemarle Road Apt 6A  2625    3      1  Brooklyn
# 867                              92ND ST  3000    3      2  Brooklyn
# 886                      East 5th Street  2600    3      1  Brooklyn
# 992                             23RD AVE  2400    3      1  Brooklyn
# 1000                       Bay 22 Street  1800    3      1  Brooklyn
# 1016                            Front St  6044    3      2  Brooklyn
# 1087                           40 Street  2170    3      1  Brooklyn
# 1097                           68 Street  2270    3      1  Brooklyn
# 1119                         Colonial Rd  2400    3      1  Brooklyn
# 1141                     636 Saint Marks  2725    3      1  Brooklyn
# 1169                            Front St  7815    3      2  Brooklyn
# 1184                           51 Street  2350    3      2  Brooklyn
# 1267   NO FEE! Spacious Charming 3 Br...  3000    3      2  Brooklyn
# 1315                           Halsey st  2550    3      1  Brooklyn
# 1347                         73rd Street  2800    3      1  Brooklyn
# 1519                         68th street  2400    3      1  Brooklyn
# 1527             184 Ocean Parkway Apt 3  2300    3      1  Brooklyn
# 1573                  629 Westminster Rd  2700    3      1  Brooklyn
# 1621                      Battery Avenue  2600    3      1  Brooklyn
# ...                                  ...   ...  ...    ...       ...
# 35507          1266 E. 73rd Street Apt 2  2350    3      1  Brooklyn
# 35569           321 Wythe Avenue Apt PH1  7250    3      2  Brooklyn
# 35610            2016 Regent Pl Apt 4A4A  2795    3      1  Brooklyn
# 35770           1400 Jefferson Ave Apt B  2300    3      1  Brooklyn
# 35776           206 Nassau Avenue Apt 2L  3870    3      2  Brooklyn
# 35837            194 Ralph Avenue Apt 3B  2475    3      1  Brooklyn
# 35884        244 Bainbridge Street Apt 4  2433    3      1  Brooklyn
# 35897              21 Pilling St Apt FL2  2800    3      1  Brooklyn
# 35907           1544 Nostrand Ave Apt 2F   950    3      2  Brooklyn
# 35908              90 Sullivan Pl Apt C5  3450    3      2  Brooklyn
# 35989         643 Franklin Avenue Apt 1R  2793    3      1  Brooklyn
# 36077                           Front St  7196    3      2  Brooklyn
# 36103                 90 South 1st Apt 1  5875    3      3  Brooklyn
# 36123         471 Chauncey Street Apt 2L  2500    3      1  Brooklyn
# 36139           498 Clinton Avenue Apt 2  4250    3      3  Brooklyn
# 36152           206 Nassau Avenue Apt 4L  3750    3      2  Brooklyn
# 36277        163 North 6th Street Apt C2  5000    3      3  Brooklyn
# 36294                         4th Avenue  2700    3      1  Brooklyn
# 36346    248 Mckibbin Street Brooklyn...  3275    3      1  Brooklyn
# 36460                 309 Bedford Avenue  3200    3      1  Brooklyn
# 36533              400 Douglass St Apt 2  4750    3      1  Brooklyn
# 36549                    818 prospect pl  2750    3      1  Brooklyn
# 36634              570 Evergreen Apt 2LW  2667    3      2  Brooklyn
# 36661         90 South 1st Street Apt 1A  5875    3      2  Brooklyn
# 36668            307 Grand Street Apt 3B  4499    3      2  Brooklyn
# 36674          49 Rochester Avenue Apt 3  2700    3      2  Brooklyn
# 36696        244 Bainbridge Street Apt 4  2548    3      1  Brooklyn
# 36701           385 Vernon Avenue Apt 2D  2800    3      1  Brooklyn
# 36717          82 Saratoga Avenue Apt 3L  2450    3      1  Brooklyn
# 36730                    Duffield Street  6385    3      2  Brooklyn
#
#                      hood  elevator  doorman  laundry  furnished    sqft  page
# 29           Williamsburg     False    False     True      False   900.0    43
# 49      East Williamsburg     False    False    False      False  1500.0    42
# 59     Bedford-Stuyvesant      True    False    False      False     NaN    41
# 101          Williamsburg     False    False    False      False     NaN    37
# 131     Downtown Brooklyn     False    False     True      False     NaN    35
# 274             Bay Ridge     False    False    False      False  1100.0  2819
# 354          Clinton Hill     False    False    False      False     NaN  2806
# 564          Clinton Hill      True    False    False      False     NaN  2782
# 752    Bedford-Stuyvesant     False    False    False      False     NaN  2762
# 753    Bedford-Stuyvesant      True    False    False      False     NaN  2762
# 821         East Flatbush     False    False    False      False     NaN  2753
# 823              Flatbush      True    False    False      False     NaN  2753
# 867         Dyker Heights     False    False     True      False  1500.0  2742
# 886            Kensington     False    False    False      False     NaN  2740
# 992             Gravesend     False    False     True      False  1200.0  2728
# 1000           Bath Beach     False    False    False      False     NaN  2728
# 1016                DUMBO      True     True    False      False     NaN  2727
# 1087          Sunset Park     False    False    False      False     NaN  2722
# 1097        Dyker Heights     False    False    False      False     NaN  2721
# 1119            Bay Ridge     False    False    False      False  1000.0  2720
# 1141        Crown Heights     False    False    False      False     NaN  2719
# 1169                DUMBO      True     True    False      False     NaN  2717
# 1184          Sunset Park     False    False    False      False   800.0  2716
# 1267   Bedford-Stuyvesant     False    False    False      False     NaN  2711
# 1315             Bushwick     False    False    False      False     NaN  2706
# 1347            Bay Ridge     False    False    False      False     NaN  2703
# 1519        Dyker Heights     False    False    False      False     NaN  2692
# 1527           Kensington     False    False    False      False     NaN  2692
# 1573             Flatbush     False    False    False      False     NaN  2689
# 1621        Dyker Heights     False    False    False      False     NaN  2686
# ...                   ...       ...      ...      ...        ...     ...   ...
# 35507          Georgetown     False    False    False      False     NaN   180
# 35569        Williamsburg      True     True    False      False  1500.0   175
# 35610            Flatbush     False    False    False      False     NaN   169
# 35770            Bushwick     False    False    False      False     NaN   152
# 35776          Greenpoint     False    False    False      False     NaN   151
# 35837  Bedford-Stuyvesant     False    False    False      False     NaN   144
# 35884  Bedford-Stuyvesant     False    False    False      False     NaN   139
# 35897            Bushwick     False    False    False      False     NaN   138
# 35907            Flatbush     False    False    False      False     NaN   137
# 35908       Crown Heights     False    False    False      False     NaN   137
# 35989       Crown Heights     False    False    False      False     NaN   128
# 36077               DUMBO      True     True     True      False     NaN   117
# 36103        Williamsburg      True    False     True      False  1500.0   113
# 36123          Ocean Hill     False    False    False      False     NaN   110
# 36139        Clinton Hill     False    False    False      False     NaN   108
# 36152          Greenpoint     False    False    False      False     NaN   107
# 36277        Williamsburg     False    False     True      False  1100.0    93
# 36294   Greenwood Heights     False    False    False      False     NaN    91
# 36346   East Williamsburg     False    False    False      False   925.0    84
# 36460        Williamsburg     False    False    False      False     NaN    67
# 36533         North Slope     False    False    False      False     NaN    54
# 36549       Crown Heights     False    False    False      False     NaN    52
# 36634            Bushwick     False    False    False      False     NaN    24
# 36661        Williamsburg     False    False     True      False  1600.0    18
# 36668        Williamsburg     False    False    False      False   800.0    17
# 36674  Bedford-Stuyvesant     False    False    False      False     NaN    16
# 36696  Bedford-Stuyvesant     False     True    False      False     NaN    12
# 36701  Bedford-Stuyvesant     False    False    False      False     NaN    11
# 36717  Bedford-Stuyvesant     False    False     True      False     NaN     9
# 36730   Downtown Brooklyn      True     True     True      False     NaN     7
#
# [871 rows x 12 columns]

# %%
plt.figure(figsize=(12,6))
brook.groupby('hood')['rent'].median().sort_values(ascending=False).plot.bar(color='b', title = "Median 3 Bed Rent")

# %%
plt.figure(figsize=(12,6))
brook.groupby('hood')['rent'].count().sort_values(ascending=False).plot.bar(color='b', title = "Number of 3 Beds Available")

# %%
greenpoint = brook.loc[brook['hood'] == 'Greenpoint']

# %%
greenpoint = greenpoint.reset_index(drop=True)
greenpoint.sort_values(by='rent', ascending=False)
# Out:
#                              address  rent beds  baths   borough        hood  \
# 17                         Blue Slip  7892    3      2  Brooklyn  Greenpoint
# 11                        Greenpoint  7892    3      1  Brooklyn  Greenpoint
# 6                          Blue Slip  7491    3      2  Brooklyn  Greenpoint
# 15                         Blue Slip  7475    3      2  Brooklyn  Greenpoint
# 32                         Blue Slip  7471    3      2  Brooklyn  Greenpoint
# 12               1 Blue Slip Apt 25C  7450    3      2  Brooklyn  Greenpoint
# 9                          Blue Slip  7398    3      2  Brooklyn  Greenpoint
# 18                         Blue Slip  7375    3      2  Brooklyn  Greenpoint
# 4                          Blue Slip  7300    3      2  Brooklyn  Greenpoint
# 25                         Blue Slip  7295    3      2  Brooklyn  Greenpoint
# 19                         Blue Slip  7285    3      2  Brooklyn  Greenpoint
# 1                          Blue Slip  5500    3      2  Brooklyn  Greenpoint
# 24             555 Graham Ave Apt 3D  4800    3      1  Brooklyn  Greenpoint
# 13                      Newel Street  4500    3      1  Brooklyn  Greenpoint
# 5                     Russell Street  4300    3      2  Brooklyn  Greenpoint
# 29         228 Kingsland Ave Apt 1BB  4100    3      2  Brooklyn  Greenpoint
# 3                      Nassau Avenue  3995    3      2  Brooklyn  Greenpoint
# 16         216 Freeman Street Apt 4A  3995    3      2  Brooklyn  Greenpoint
# 8            217 Green Street Apt 3A  3933    3      2  Brooklyn  Greenpoint
# 7                         Eckford st  3900    3      1  Brooklyn  Greenpoint
# 2                      Nassau Avenue  3875    3      2  Brooklyn  Greenpoint
# 35          206 Nassau Avenue Apt 2L  3870    3      2  Brooklyn  Greenpoint
# 23          206 Nassau Avenue Apt 2A  3869    3      2  Brooklyn  Greenpoint
# 33              217 Green St. Apt 2A  3865    3      2  Brooklyn  Greenpoint
# 34          592 Manhattan Ave Apt 3L  3800    3      2  Brooklyn  Greenpoint
# 36          206 Nassau Avenue Apt 4L  3750    3      2  Brooklyn  Greenpoint
# 22  1008 Manhattan Ave Brooklyn N...  3750    3      2  Brooklyn  Greenpoint
# 21                         Newton st  3667    3      1  Brooklyn  Greenpoint
# 20   120 Eckford Brooklyn Ny Apt ...  3645    3      2  Brooklyn  Greenpoint
# 10                106b Nassau Avenue  3550    3      1  Brooklyn  Greenpoint
# 27             85-89 Clay St Apt CR2  3500    3      1  Brooklyn  Greenpoint
# 31                77 Newel St Apt 3J  3500    3      2  Brooklyn  Greenpoint
# 30          206 Nassau Avenue Apt 2R  3495    3      2  Brooklyn  Greenpoint
# 14                    Lorimer Street  3495    3      1  Brooklyn  Greenpoint
# 28                          88 Jewel  3400    3      2  Brooklyn  Greenpoint
# 26             111 Greenpoint Avenue  3392    3      2  Brooklyn  Greenpoint
# 0           818 Manhattan Ave Apt 3R  2800    3      1  Brooklyn  Greenpoint
#
#     elevator  doorman  laundry  furnished    sqft  page
# 17      True     True     True      False     NaN  1395
# 11      True     True     True      False     NaN  1904
# 6       True     True     True      False     NaN  2164
# 15      True     True     True      False     NaN  1537
# 32      True     True     True      False     NaN   309
# 12      True     True     True      False     NaN  1897
# 9       True     True     True      False     NaN  2111
# 18      True     True     True      False     NaN  1373
# 4       True     True     True      False     NaN  2302
# 25      True     True     True      False     NaN   881
# 19      True     True     True      False     NaN  1170
# 1       True     True     True      False     NaN  2418
# 24     False    False    False      False     NaN   892
# 13     False    False    False      False     NaN  1849
# 5      False    False    False      False     NaN  2189
# 29     False    False    False      False     NaN   682
# 3      False    False     True      False     NaN  2343
# 16      True    False    False      False     NaN  1483
# 8       True     True    False      False  1500.0  2126
# 7      False    False    False      False     NaN  2139
# 2      False    False     True      False     NaN  2353
# 35     False    False    False      False     NaN   151
# 23     False    False    False      False     NaN   910
# 33      True     True    False      False  1000.0   236
# 34     False    False    False      False     NaN   182
# 36     False    False    False      False     NaN   107
# 22     False    False    False      False     NaN   915
# 21     False    False    False      False     NaN   936
# 20     False    False    False      False     NaN  1144
# 10     False    False     True      False   900.0  1917
# 27     False    False    False      False     NaN   733
# 31     False    False    False      False     NaN   378
# 30     False    False    False      False     NaN   445
# 14     False    False     True      False     NaN  1794
# 28     False    False    False      False     NaN   694
# 26     False    False    False      False  1000.0   855
# 0      False    False    False      False   980.0  2563

# %%
print(greenpoint[['address']])
#get the addresses that can be mapped
add_idx = [0, 8, 10, 12, 16, 20, 22, 23, 24, 26, 27, 28, 29, 30, 31, 33, 34]
add_to_check = greenpoint['address'][add_idx]
add_to_check
# Out:
#                              address
# 0           818 Manhattan Ave Apt 3R
# 1                          Blue Slip
# 2                      Nassau Avenue
# 3                      Nassau Avenue
# 4                          Blue Slip
# 5                     Russell Street
# 6                          Blue Slip
# 7                         Eckford st
# 8            217 Green Street Apt 3A
# 9                          Blue Slip
# 10                106b Nassau Avenue
# 11                        Greenpoint
# 12               1 Blue Slip Apt 25C
# 13                      Newel Street
# 14                    Lorimer Street
# 15                         Blue Slip
# 16         216 Freeman Street Apt 4A
# 17                         Blue Slip
# 18                         Blue Slip
# 19                         Blue Slip
# 20   120 Eckford Brooklyn Ny Apt ...
# 21                         Newton st
# 22  1008 Manhattan Ave Brooklyn N...
# 23          206 Nassau Avenue Apt 2A
# 24             555 Graham Ave Apt 3D
# 25                         Blue Slip
# 26             111 Greenpoint Avenue
# 27             85-89 Clay St Apt CR2
# 28                          88 Jewel
# 29         228 Kingsland Ave Apt 1BB
# 30          206 Nassau Avenue Apt 2R
# 31                77 Newel St Apt 3J
# 32                         Blue Slip
# 33              217 Green St. Apt 2A
# 34          592 Manhattan Ave Apt 3L
# 35          206 Nassau Avenue Apt 2L
# 36          206 Nassau Avenue Apt 4L
# 0             818 Manhattan Ave Apt 3R Brooklyn, NY
# 8              217 Green Street Apt 3A Brooklyn, NY
# 10                  106b Nassau Avenue Brooklyn, NY
# 12                 1 Blue Slip Apt 25C Brooklyn, NY
# 16           216 Freeman Street Apt 4A Brooklyn, NY
# 20     120 Eckford Brooklyn Ny Apt ... Brooklyn, NY
# 22    1008 Manhattan Ave Brooklyn N... Brooklyn, NY
# 23            206 Nassau Avenue Apt 2A Brooklyn, NY
# 24               555 Graham Ave Apt 3D Brooklyn, NY
# 26               111 Greenpoint Avenue Brooklyn, NY
# 27               85-89 Clay St Apt CR2 Brooklyn, NY
# 28                            88 Jewel Brooklyn, NY
# 29           228 Kingsland Ave Apt 1BB Brooklyn, NY
# 30            206 Nassau Avenue Apt 2R Brooklyn, NY
# 31                  77 Newel St Apt 3J Brooklyn, NY
# 33                217 Green St. Apt 2A Brooklyn, NY
# 34            592 Manhattan Ave Apt 3L Brooklyn, NY
# Name: address, dtype: object

# %%
import googlemaps
googlemap = googlemaps.Client(key='AIzaSyDiIZIOGnfNzKtD-6I0U9HkNpRsRdcTu7A')
#Below line gets commented since each request costs money
#geocode_results = list(map(lambda x: googlemap.geocode(x + 'Brooklyn, NY'), add_to_check))
geocode_results
# Out:
# [[{'address_components': [{'long_name': '3RBrooklyn',
#      'short_name': '3RBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '818', 'short_name': '818', 'types': ['street_number']},
#     {'long_name': 'Manhattan Avenue',
#      'short_name': 'Manhattan Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '818 Manhattan Ave #3RBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.7283382, 'lng': -73.9532736},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.72968718029151,
#       'lng': -73.9519246197085},
#      'southwest': {'lat': 40.72698921970851, 'lng': -73.95462258029151}}},
#    'partial_match': True,
#    'place_id': 'EjYzUkJyb29rbHluLCA4MTggTWFuaGF0dGFuIEF2ZSwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCQETxNZGWcKJEXZKjkC049PaEgozUkJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '3ABrooklyn',
#      'short_name': '3ABrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '217', 'short_name': '217', 'types': ['street_number']},
#     {'long_name': 'Green Street',
#      'short_name': 'Green St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '217 Green St #3ABrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.73398950000001,
#      'lng': -73.95254469999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.73533848029151,
#       'lng': -73.95119571970848},
#      'southwest': {'lat': 40.73264051970851, 'lng': -73.95389368029149}}},
#    'partial_match': True,
#    'place_id': 'EjEzQUJyb29rbHluLCAyMTcgR3JlZW4gU3QsIEJyb29rbHluLCBOWSAxMTIyMiwgVVNBIiYaJAoWChQKEgnP41c7OVnCiRFQ-jL_MhP0eRIKM0FCcm9va2x5bg',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '106B',
#      'short_name': '106B',
#      'types': ['street_number']},
#     {'long_name': 'Nassau Avenue',
#      'short_name': 'Nassau Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '106B Nassau Ave, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.724025, 'lng': -73.949461},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7253739802915,
#       'lng': -73.94811201970849},
#      'southwest': {'lat': 40.7226760197085, 'lng': -73.95080998029151}}},
#    'partial_match': True,
#    'place_id': 'ChIJ2wA8vEVZwokRJQVOAUfnT1M',
#    'plus_code': {'compound_code': 'P3F2+J6 New York, United States',
#     'global_code': '87G8P3F2+J6'},
#    'types': ['street_address']}],
#  [{'address_components': [{'long_name': '25CBrooklyn',
#      'short_name': '25CBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '1', 'short_name': '1', 'types': ['street_number']},
#     {'long_name': 'Blue Slip', 'short_name': 'Blue Slip', 'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '1 Blue Slip #25CBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.7367009, 'lng': -73.9593356},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.73804988029149,
#       'lng': -73.9579866197085},
#      'southwest': {'lat': 40.7353519197085, 'lng': -73.96068458029151}}},
#    'partial_match': True,
#    'place_id': 'EjEyNUNCcm9va2x5biwgMSBCbHVlIFNsaXAsIEJyb29rbHluLCBOWSAxMTIyMiwgVVNBIicaJQoWChQKEgm9MocAFlnCiRGUaf_zrMJD_xILMjVDQnJvb2tseW4',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '4ABrooklyn',
#      'short_name': '4ABrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '216', 'short_name': '216', 'types': ['street_number']},
#     {'long_name': 'Freeman Street',
#      'short_name': 'Freeman St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '216 Freeman St #4ABrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.7345802, 'lng': -73.9527871},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7359291802915,
#       'lng': -73.95143811970848},
#      'southwest': {'lat': 40.7332312197085, 'lng': -73.9541360802915}}},
#    'partial_match': True,
#    'place_id': 'EjM0QUJyb29rbHluLCAyMTYgRnJlZW1hbiBTdCwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCYcr1Ts5WcKJEWTgWTjLhO6dEgo0QUJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '120',
#      'short_name': '120',
#      'types': ['street_number']},
#     {'long_name': 'Eckford Street',
#      'short_name': 'Eckford St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3225',
#      'short_name': '3225',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '120 Eckford St, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.723793, 'lng': -73.94850000000001},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7251419802915,
#       'lng': -73.94715101970851},
#      'southwest': {'lat': 40.7224440197085, 'lng': -73.94984898029152}}},
#    'place_id': 'ChIJaU_TkUVZwokRWgmLcno35vs',
#    'plus_code': {'compound_code': 'P3F2+GH New York, United States',
#     'global_code': '87G8P3F2+GH'},
#    'types': ['street_address']}],
#  [{'address_components': [{'long_name': '1008',
#      'short_name': '1008',
#      'types': ['street_number']},
#     {'long_name': 'Manhattan Avenue',
#      'short_name': 'Manhattan Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '1008 Manhattan Ave, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7334975,
#       'lng': -73.9544137},
#      'southwest': {'lat': 40.7334094, 'lng': -73.9546644}},
#     'location': {'lat': 40.7334665, 'lng': -73.9544724},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7348024302915,
#       'lng': -73.95319006970851},
#      'southwest': {'lat': 40.7321044697085, 'lng': -73.95588803029152}}},
#    'place_id': 'ChIJ14COJj9ZwokRz0GRU1mfcJw',
#    'types': ['premise']}],
#  [{'address_components': [{'long_name': '2ABrooklyn',
#      'short_name': '2ABrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '206', 'short_name': '206', 'types': ['street_number']},
#     {'long_name': 'Nassau Avenue',
#      'short_name': 'Nassau Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3582',
#      'short_name': '3582',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '206 Nassau Ave #2ABrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7255244, 'lng': -73.944558},
#      'southwest': {'lat': 40.7253583, 'lng': -73.9446748}},
#     'location': {'lat': 40.72545, 'lng': -73.944648},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7267903302915,
#       'lng': -73.9432674197085},
#      'southwest': {'lat': 40.7240923697085, 'lng': -73.94596538029151}}},
#    'partial_match': True,
#    'place_id': 'EjMyQUJyb29rbHluLCAyMDYgTmFzc2F1IEF2ZSwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCdmZVyhJWcKJEeORp4KuJ0DhEgoyQUJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '3DBrooklyn',
#      'short_name': '3DBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '555', 'short_name': '555', 'types': ['street_number']},
#     {'long_name': 'Graham Avenue',
#      'short_name': 'Graham Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '4606',
#      'short_name': '4606',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '555 Graham Ave #3DBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7221757,
#       'lng': -73.9473175},
#      'southwest': {'lat': 40.721974, 'lng': -73.94770299999999}},
#     'location': {'lat': 40.7220899, 'lng': -73.9474905},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7234238302915,
#       'lng': -73.9461612697085},
#      'southwest': {'lat': 40.7207258697085, 'lng': -73.9488592302915}}},
#    'partial_match': True,
#    'place_id': 'EjMzREJyb29rbHluLCA1NTUgR3JhaGFtIEF2ZSwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCU_KqYlPWcKJEWpCuvW6Iu8rEgozREJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '111',
#      'short_name': '111',
#      'types': ['street_number']},
#     {'long_name': 'Greenpoint Avenue',
#      'short_name': 'Greenpoint Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '111 Greenpoint Ave, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7303618,
#       'lng': -73.9556838},
#      'southwest': {'lat': 40.7301638, 'lng': -73.955901}},
#     'location': {'lat': 40.7302811, 'lng': -73.9557808},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7316117802915,
#       'lng': -73.9544434197085},
#      'southwest': {'lat': 40.7289138197085, 'lng': -73.9571413802915}}},
#    'partial_match': True,
#    'place_id': 'ChIJ-X9TjUBZwokRUY9w11wQBCQ',
#    'types': ['premise']}],
#  [{'address_components': [{'long_name': '89',
#      'short_name': '89',
#      'types': ['subpremise']},
#     {'long_name': '85', 'short_name': '85', 'types': ['street_number']},
#     {'long_name': 'Clay Street', 'short_name': 'Clay St', 'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '1239',
#      'short_name': '1239',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '85 Clay St #89, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.7368907, 'lng': -73.9543454},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.73823968029149,
#       'lng': -73.95299641970848},
#      'southwest': {'lat': 40.73554171970849, 'lng': -73.95569438029149}}},
#    'partial_match': True,
#    'place_id': 'ChIJzdzhDzxZwokRNGjOMK2QB5Q',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '88',
#      'short_name': '88',
#      'types': ['street_number']},
#     {'long_name': 'Jewel Street',
#      'short_name': 'Jewel St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3013',
#      'short_name': '3013',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '88 Jewel St, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.72831499999999,
#       'lng': -73.9470504},
#      'southwest': {'lat': 40.7282227, 'lng': -73.9472371}},
#     'location': {'lat': 40.7282735, 'lng': -73.9471255},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7296178302915,
#       'lng': -73.94579476970848},
#      'southwest': {'lat': 40.7269198697085, 'lng': -73.94849273029149}}},
#    'partial_match': True,
#    'place_id': 'ChIJ7zpYekhZwokR8LJGUgRdcJ8',
#    'types': ['premise']}],
#  [{'address_components': [{'long_name': '1BBBrooklyn',
#      'short_name': '1BBBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '228', 'short_name': '228', 'types': ['street_number']},
#     {'long_name': 'Kingsland Avenue',
#      'short_name': 'Kingsland Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '4332',
#      'short_name': '4332',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '228 Kingsland Ave #1BBBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.72464799999999,
#       'lng': -73.9411117},
#      'southwest': {'lat': 40.7245554, 'lng': -73.9413727}},
#     'location': {'lat': 40.724596, 'lng': -73.9412332},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7259506802915,
#       'lng': -73.9398932197085},
#      'southwest': {'lat': 40.7232527197085, 'lng': -73.9425911802915}}},
#    'partial_match': True,
#    'place_id': 'EjcxQkJCcm9va2x5biwgMjI4IEtpbmdzbGFuZCBBdmUsIEJyb29rbHluLCBOWSAxMTIyMiwgVVNBIicaJQoWChQKEgkPMEz4S1nCiRHwOoIWTBxdBRILMUJCQnJvb2tseW4',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '2RBrooklyn',
#      'short_name': '2RBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '206', 'short_name': '206', 'types': ['street_number']},
#     {'long_name': 'Nassau Avenue',
#      'short_name': 'Nassau Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3582',
#      'short_name': '3582',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '206 Nassau Ave #2RBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7255244, 'lng': -73.944558},
#      'southwest': {'lat': 40.7253583, 'lng': -73.9446748}},
#     'location': {'lat': 40.72545, 'lng': -73.944648},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7267903302915,
#       'lng': -73.9432674197085},
#      'southwest': {'lat': 40.7240923697085, 'lng': -73.94596538029151}}},
#    'partial_match': True,
#    'place_id': 'EjMyUkJyb29rbHluLCAyMDYgTmFzc2F1IEF2ZSwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCdmZVyhJWcKJEeORp4KuJ0DhEgoyUkJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '3JBrooklyn',
#      'short_name': '3JBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '77', 'short_name': '77', 'types': ['street_number']},
#     {'long_name': 'Newel Street',
#      'short_name': 'Newel St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3303',
#      'short_name': '3303',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '77 Newel St #3JBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7251201,
#       'lng': -73.9476906},
#      'southwest': {'lat': 40.7250283, 'lng': -73.9478456}},
#     'location': {'lat': 40.7250676, 'lng': -73.9477728},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7264231802915,
#       'lng': -73.94641911970851},
#      'southwest': {'lat': 40.7237252197085, 'lng': -73.94911708029151}}},
#    'partial_match': True,
#    'place_id': 'EjAzSkJyb29rbHluLCA3NyBOZXdlbCBTdCwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCTGdVP9FWcKJEYL-59n73HZHEgozSkJyb29rbHlu',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '2ABrooklyn',
#      'short_name': '2ABrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '217', 'short_name': '217', 'types': ['street_number']},
#     {'long_name': 'Green Street',
#      'short_name': 'Green St',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']}],
#    'formatted_address': '217 Green St #2ABrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'location': {'lat': 40.73398950000001,
#      'lng': -73.95254469999999},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.73533848029151,
#       'lng': -73.95119571970848},
#      'southwest': {'lat': 40.73264051970851, 'lng': -73.95389368029149}}},
#    'partial_match': True,
#    'place_id': 'EjEyQUJyb29rbHluLCAyMTcgR3JlZW4gU3QsIEJyb29rbHluLCBOWSAxMTIyMiwgVVNBIiYaJAoWChQKEgnP41c7OVnCiRFQ-jL_MhP0eRIKMkFCcm9va2x5bg',
#    'types': ['subpremise']}],
#  [{'address_components': [{'long_name': '3LBrooklyn',
#      'short_name': '3LBrooklyn',
#      'types': ['subpremise']},
#     {'long_name': '592', 'short_name': '592', 'types': ['street_number']},
#     {'long_name': 'Manhattan Avenue',
#      'short_name': 'Manhattan Ave',
#      'types': ['route']},
#     {'long_name': 'Greenpoint',
#      'short_name': 'Greenpoint',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Brooklyn',
#      'short_name': 'Brooklyn',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Kings County',
#      'short_name': 'Kings County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '11222', 'short_name': '11222', 'types': ['postal_code']},
#     {'long_name': '3913',
#      'short_name': '3913',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '592 Manhattan Ave #3LBrooklyn, Brooklyn, NY 11222, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 40.7231035,
#       'lng': -73.95004999999999},
#      'southwest': {'lat': 40.7229744, 'lng': -73.9502869}},
#     'location': {'lat': 40.7230425, 'lng': -73.9501451},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.7243879302915,
#       'lng': -73.9488194697085},
#      'southwest': {'lat': 40.7216899697085, 'lng': -73.9515174302915}}},
#    'partial_match': True,
#    'place_id': 'EjYzTEJyb29rbHluLCA1OTIgTWFuaGF0dGFuIEF2ZSwgQnJvb2tseW4sIE5ZIDExMjIyLCBVU0EiJhokChYKFAoSCSEw-gZFWcKJEeFcgTWyqmcMEgozTEJyb29rbHlu',
#    'types': ['subpremise']}]]

# %%
import gmaps
gmaps.configure(api_key='AIzaSyDiIZIOGnfNzKtD-6I0U9HkNpRsRdcTu7A')

lats = []
longs = []

for geocode_result in geocode_results:
    coords=geocode_result[0].get('geometry')
    lat, long = coords.get('location')['lat'], coords.get('location')['lng']
    lats += [lat]
    longs += [long]

marker_locations = list(zip(lats, longs))
avg_lat = sum(lats)/len(lats)
avg_long = sum(longs)/len(longs)


#new_york_coordinates = (40.75, -74.00)
fig = gmaps.figure(center=(avg_lat, avg_long), zoom_level=14)
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
